# %%
import numpy as np

# %%
data = [[0.2*x - 0.5 for x in range(2+y,10+y,2)] for y in range(10, 31, 10)]
arr = np.array(data)
arr
# Out:
# array([[1.9, 2.3, 2.7, 3.1],
#        [3.9, 4.3, 4.7, 5.1],
#        [5.9, 6.3, 6.7, 7.1]])

# %%
print(arr.shape, arr.ndim, arr.dtype)
# Out:
# (3, 4) 2 float64

# %%
# %load rapid_imports.py
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
arr = np.cumsum(np.random.randint(0, 2, size=100)*2 - 1)
plt.plot(arr)
ind = (np.abs(arr) > 10).argmax()
plt.axvline(ind, c='red', linestyle='--')
plt.axhline(arr[ind], c='g', linestyle=':')

# %%
(np.abs(arr) > 10).argmax()
# Out:
# 78

# %%
np.argmax?
