# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %%
plt.plot(np.random.randn(50).cumsum())
plt.grid(True)

# %% [markdown]
# ## Magic Commands

# %%
# %run rapid_imports.py
# %matplotlib inline

# %%
df = pd.DataFrame([{'n':n, 'x':np.random.randn()} for n in range(10**4)])
sns.histplot(data=df,
             x='x',
             kde=True,
             bins=np.arange(-3,3,0.5))

# %%
# %load rapid_imports.py

# %%
# %timeit [x**x for x in range(1000)]
# Out:
# 23.2 ms ± 469 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %pwd
# Out:
# 'F:\\Study\\repos\\useful_commands'

# %% [markdown]
# ## Help

# %%
# docstring
print?

# %%
# source code
pd.DataFrame??

# %%
# search by wildcard
np.*add*?
